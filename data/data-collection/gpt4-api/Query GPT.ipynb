# %%
import openai
import csv
import pandas as pd

# Set your OpenAI API key
API_KEY = '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'
API_ENDPOINT = "https://api.openai.com/v1/chat/completions"

# Read data from your CSV file
data = pd.read_csv('/Users/svenschnydrig/Library/CloudStorage/OneDrive-SharedLibraries-UniversitätSt.Gallen/STUD-NLP Group Project - General/02 Group project/data/generated-data/working-folder/mb16.csv')

responses = []
contexts = []

for i, row in data.iterrows():
    print(i)

    paragraph = row['paragraph']
    prompt = f"Please create as many high quality question/answer pairs as possible in a similar style as the squad dataset to finetune a bert model based on the following german context text. the answer should be copied one to one from the context text. Give your output in that format: 'question -|- answer -|-'. Give me only the output in that format and no other comments. Here is the context text:': \n'{paragraph}'"
    print(prompt)
    print('\n')

    # Query the GPT-4 API
    message=[{"role": "user", "content": prompt}]

    response = openai.ChatCompletion.create(
    model="gpt-4",
    temperature=0.3,
    messages = message)

    print(response['choices'][0]['message']['content'])
    print('\n')

    # Save the response
    responses.append(response['choices'][0]['message']['content'])
    contexts.append(paragraph)

# create datframe with context and response
output_data = pd.DataFrame({'context': contexts, 'answer': responses})

# write the output to an excel file
output_data.to_excel('mb16_output.xlsx', index=False, header=False)

# Write the output to another CSV file with '|' delimiter and without header row
output_data.to_csv('mb16_output.csv', index=False, sep=';', header=False)
# Out:
# 0
# Please create as many high quality question/answer pairs as possible in a similar style as the squad dataset to finetune a bert model based on the following german context text. the answer should be copied one to one from the context text. Give your output in that format: 'question -|- answer -|-'. Give me only the output in that format and no other comments. Here is the context text:':
# 'Unter dem Begriff «berufliche Grundbildung» versteht man eine Berufsbildung, die in der Regel an die obligatorische Schulzeit anschliesst. Wer eine berufliche Grundbildung durchläuft, lernt alles Wichtige für eine Tätigkeit in einem Beruf. Je nach Dauer und Inhalt wird die berufliche Grundbildung mit einem eidgenössischen Fähigkeitszeugnis EFZ oder mit einem eidgenössischen Berufsattest EBA abgeschlossen.'
#
#
# Was versteht man unter dem Begriff "berufliche Grundbildung"? -|- eine Berufsbildung, die in der Regel an die obligatorische Schulzeit anschliesst. -|-
# ...

# %%
import openai
import csv
import pandas as pd
import os

# Set your OpenAI API key
API_KEY = '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'
API_ENDPOINT = "https://api.openai.com/v1/chat/completions"

path = ('/Users/svenschnydrig/Library/CloudStorage/OneDrive-SharedLibraries-UniversitätSt.Gallen/STUD-NLP Group Project - General/02 Group project/data/generated-data/working-folder/mb17.csv')
name = os.path.splitext(os.path.basename(path))[0][-4:]

# Read data from your CSV file
data = pd.read_csv(path)

responses = []
contexts = []

for i, row in data.iterrows():
    print(i)
    paragraph = row['paragraph']
    prompt = f"Please create as many high quality question/answer pairs as possible in a similar style as the squad dataset to finetune a bert model based on the following german context text. the answer should be copied one to one from the context text. Give your output in that format: 'question -|- answer -|-'. Give me only the output in that format and no other comments. Here is the context text:': \n'{paragraph}'"
    print(prompt)
    print('\n')

    # Query the GPT-4 API
    message=[{"role": "user", "content": prompt}]

    response = openai.ChatCompletion.create(
    model="gpt-4",
    temperature=0.3,
    messages = message)

    print(response['choices'][0]['message']['content'])
    print('\n')

    # Save the response
    responses.append(response['choices'][0]['message']['content'])
    contexts.append(paragraph)

# create datframe with context and response
df = pd.DataFrame({'context': contexts, 'output': responses})

# write the output to an excel file
df.to_excel(name+'_output.xlsx', index=False, header=False)

# Write the output to another CSV file with '|' delimiter and without header row
df.to_csv(name+'_output.csv', index=False, sep=';', header=False)

df['output'] = df['output'].apply(lambda s: s[:-3])

c = []
q = []
a = []

for row in df.itertuples():
    ## Retrieving data for each row
    context = str(row.context)
    output = str(row.output)
    
    ## Removing “\n" in each string and splitting into question / answer pairs
    output = output.replace('\n', '')
    output = output.split('-|-')
    for i in range(0, len(output) - 1, 2):
        c.append(context)
        q.append(output[i])
        a.append(output[i+1])

tidy_df = pd.DataFrame({'context': c, 'question': q, 'answer': a})

# save tidy_df to csv
tidy_df.to_csv(name+'_tidy.csv', index=False, sep='|', header=False)

#save tidy_df to excel
tidy_df.to_excel(name+'_tidy.xlsx', index=False, header=False)
# Out:
# 0
# Please create as many high quality question/answer pairs as possible in a similar style as the squad dataset to finetune a bert model based on the following german context text. the answer should be copied one to one from the context text. Give your output in that format: 'question -|- answer -|-'. Give me only the output in that format and no other comments. Here is the context text:':
# 'Lernende Personen schliessen eine berufliche Grundbildung meist im Alter von 18 oder 19 Jahren ab. Im Normalfall absolvieren die militärdienstpflichtigen Schweizer oder die freiwillig dienstleistenden Schweizerinnen die Rekrutenschule (RS) direkt nach ihrer ersten beruflichen Grundbildung.'
#
#
# Wann schließen Lernende in der Regel ihre berufliche Grundbildung ab? -|- im Alter von 18 oder 19 Jahren -|-
# ...

# %%
path = ('/Users/svenschnydrig/Library/CloudStorage/OneDrive-SharedLibraries-UniversitätSt.Gallen/STUD-NLP Group Project - General/02 Group project/data/generated-data/working-folder/mb19.csv')
name = os.path.splitext(os.path.basename(path))[0][-4:]

# Read data from your CSV file
df = pd.read_csv(path)

# Assuming 'mb19' is your DataFrame
df['paragraph'] = df['paragraph'].replace('\n',' ', regex=True) # replace newline with space
df['paragraph'] = df['paragraph'].replace('\s+',' ', regex=True) # replace multiple spaces with single space
# If you want to strip leading and trailing spaces as well
df['paragraph'] = df['paragraph'].str.strip()

# %% [markdown]
# # MB 19

# %%
import openai
import csv
import pandas as pd
import os

# Set your OpenAI API key
API_KEY = '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'
API_ENDPOINT = "https://api.openai.com/v1/chat/completions"

path = ('/Users/svenschnydrig/Library/CloudStorage/OneDrive-SharedLibraries-UniversitätSt.Gallen/STUD-NLP Group Project - General/02 Group project/data/generated-data/working-folder/mb19.csv')
name = os.path.splitext(os.path.basename(path))[0][-4:]

# Read data from your CSV file
data = pd.read_csv(path)

# Assuming 'mb19' is your DataFrame
data['paragraph'] = data['paragraph'].replace('\n',' ', regex=True) # replace newline with space
data['paragraph'] = data['paragraph'].replace('\s+',' ', regex=True) # replace multiple spaces with single space
# If you want to strip leading and trailing spaces as well
data['paragraph'] = data['paragraph'].str.strip()

responses = []
contexts = []

for i, row in data.iterrows():
    print(i)
    paragraph = row['paragraph']
    prompt = f"Please create as many high quality question/answer pairs as possible in a similar style as the squad dataset to finetune a bert model based on the following german context text. the answer should be copied one to one from the context text. Give your output in that format: 'question -|- answer -|-'. Give me only the output in that format and no other comments. Here is the context text:': \n'{paragraph}'"
    print(prompt)
    print('\n')

    # Query the GPT-4 API
    message=[{"role": "user", "content": prompt}]

    response = openai.ChatCompletion.create(
    model="gpt-4",
    temperature=0.3,
    messages = message)

    print(response['choices'][0]['message']['content'])
    print('\n')

    # Save the response
    responses.append(response['choices'][0]['message']['content'])
    contexts.append(paragraph)

# create datframe with context and response
df = pd.DataFrame({'context': contexts, 'output': responses})

# write the output to an excel file
df.to_excel(name+'_output.xlsx', index=False, header=False)

# Write the output to another CSV file with '|' delimiter and without header row
df.to_csv(name+'_output.csv', index=False, sep=';', header=False)

df['output'] = df['output'].apply(lambda s: s[:-3])

c = []
q = []
a = []

for row in df.itertuples():
    ## Retrieving data for each row
    context = str(row.context)
    output = str(row.output)
    
    ## Removing “\n" in each string and splitting into question / answer pairs
    output = output.replace('\n', '')
    output = output.split('-|-')
    for i in range(0, len(output) - 1, 2):
        c.append(context)
        q.append(output[i])
        a.append(output[i+1])

tidy_df = pd.DataFrame({'context': c, 'question': q, 'answer': a})

# save tidy_df to csv
tidy_df.to_csv(name+'_tidy.csv', index=False, sep='|', header=False)

#save tidy_df to excel
tidy_df.to_excel(name+'_tidy.xlsx', index=False, header=False)
# Out:
# 0
# Please create as many high quality question/answer pairs as possible in a similar style as the squad dataset to finetune a bert model based on the following german context text. the answer should be copied one to one from the context text. Give your output in that format: 'question -|- answer -|-'. Give me only the output in that format and no other comments. Here is the context text:':
# ...

# %% [markdown]
# # MB20-301

# %%
import openai
import csv
import pandas as pd
import os

# Set your OpenAI API key
API_KEY = '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'
API_ENDPOINT = "https://api.openai.com/v1/chat/completions"

path = ('/Users/svenschnydrig/Library/CloudStorage/OneDrive-SharedLibraries-UniversitätSt.Gallen/STUD-NLP Group Project - General/02 Group project/data/Group project/mb20_301.csv')
name = os.path.splitext(os.path.basename(path))[0][-8:]

# Read data from your CSV file
data = pd.read_csv(path)

# Assuming 'mb19' is your DataFrame
data['paragraph'] = data['paragraph'].replace('\n',' ', regex=True) # replace newline with space
data['paragraph'] = data['paragraph'].replace('\s+',' ', regex=True) # replace multiple spaces with single space
# If you want to strip leading and trailing spaces as well
data['paragraph'] = data['paragraph'].str.strip()

responses = []
contexts = []

for i, row in data.iterrows():
    print(i)
    paragraph = row['paragraph']
    prompt = f"Please create as many high quality question/answer pairs as possible in a similar style as the squad dataset to finetune a bert model based on the following german context text. the answer should be copied one to one from the context text. Give your output in that format: 'question -|- answer -|-'. Give me only the output in that format and no other comments. Here is the context text:': \n'{paragraph}'"
    print(prompt)
    print('\n')

    # Query the GPT-4 API
    message=[{"role": "user", "content": prompt}]

    response = openai.ChatCompletion.create(
    model="gpt-4",
    temperature=0.3,
    messages = message)

    print(response['choices'][0]['message']['content'])
    print('\n')

    # Save the response
    responses.append(response['choices'][0]['message']['content'])
    contexts.append(paragraph)

# create datframe with context and response
df = pd.DataFrame({'context': contexts, 'output': responses})

# write the output to an excel file
df.to_excel(name+'_output.xlsx', index=False, header=False)

# Write the output to another CSV file with '|' delimiter and without header row
df.to_csv(name+'_output.csv', index=False, sep=';', header=False)

df['output'] = df['output'].apply(lambda s: s[:-3])

c = []
q = []
a = []

for row in df.itertuples():
    ## Retrieving data for each row
    context = str(row.context)
    output = str(row.output)
    
    ## Removing “\n" in each string and splitting into question / answer pairs
    output = output.replace('\n', '')
    output = output.split('-|-')
    for i in range(0, len(output) - 1, 2):
        c.append(context)
        q.append(output[i])
        a.append(output[i+1])

tidy_df = pd.DataFrame({'context': c, 'question': q, 'answer': a})

# save tidy_df to csv
tidy_df.to_csv(name+'_tidy.csv', index=False, sep='|', header=False)

#save tidy_df to excel
tidy_df.to_excel(name+'_tidy.xlsx', index=False, header=False)
# Out:
# 0
# Please create as many high quality question/answer pairs as possible in a similar style as the squad dataset to finetune a bert model based on the following german context text. the answer should be copied one to one from the context text. Give your output in that format: 'question -|- answer -|-'. Give me only the output in that format and no other comments. Here is the context text:':
# ...

# %% [markdown]
# # MB302-303

# %%
import openai
import csv
import pandas as pd
import os

# Set your OpenAI API key
API_KEY = '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'
API_ENDPOINT = "https://api.openai.com/v1/chat/completions"

path = ('/Users/svenschnydrig/Library/CloudStorage/OneDrive-SharedLibraries-UniversitätSt.Gallen/STUD-NLP Group Project - General/02 Group project/data/Group project/mb302_303.csv')
name = os.path.splitext(os.path.basename(path))[0][-9:]

# Read data from your CSV file
data = pd.read_csv(path)

# Assuming 'mb19' is your DataFrame
data['paragraph'] = data['paragraph'].replace('\n',' ', regex=True) # replace newline with space
data['paragraph'] = data['paragraph'].replace('\s+',' ', regex=True) # replace multiple spaces with single space
# If you want to strip leading and trailing spaces as well
data['paragraph'] = data['paragraph'].str.strip()

responses = []
contexts = []

for i, row in data.iterrows():
    print(i)
    paragraph = row['paragraph']
    prompt = f"Please create as many high quality question/answer pairs as possible in a similar style as the squad dataset to finetune a bert model based on the following german context text. the answer should be copied one to one from the context text. Give your output in that format: 'question -|- answer -|-'. Give me only the output in that format and no other comments. Here is the context text:': \n'{paragraph}'"
    print(prompt)
    print('\n')

    # Query the GPT-4 API
    message=[{"role": "user", "content": prompt}]

    response = openai.ChatCompletion.create(
    model="gpt-4",
    temperature=0.3,
    messages = message)

    print(response['choices'][0]['message']['content'])
    print('\n')

    # Save the response
    responses.append(response['choices'][0]['message']['content'])
    contexts.append(paragraph)

# create datframe with context and response
df = pd.DataFrame({'context': contexts, 'output': responses})

# write the output to an excel file
df.to_excel(name+'_output.xlsx', index=False, header=False)

# Write the output to another CSV file with '|' delimiter and without header row
df.to_csv(name+'_output.csv', index=False, sep=';', header=False)

df['output'] = df['output'].apply(lambda s: s[:-3])

c = []
q = []
a = []

for row in df.itertuples():
    ## Retrieving data for each row
    context = str(row.context)
    output = str(row.output)
    
    ## Removing “\n" in each string and splitting into question / answer pairs
    output = output.replace('\n', '')
    output = output.split('-|-')
    for i in range(0, len(output) - 1, 2):
        c.append(context)
        q.append(output[i])
        a.append(output[i+1])

tidy_df = pd.DataFrame({'context': c, 'question': q, 'answer': a})

# save tidy_df to csv
tidy_df.to_csv(name+'_tidy.csv', index=False, sep='|', header=False)

#save tidy_df to excel
tidy_df.to_excel(name+'_tidy.xlsx', index=False, header=False)
# Out:
# 0
# Please create as many high quality question/answer pairs as possible in a similar style as the squad dataset to finetune a bert model based on the following german context text. the answer should be copied one to one from the context text. Give your output in that format: 'question -|- answer -|-'. Give me only the output in that format and no other comments. Here is the context text:':
# 'Das Arbeitsgesetz Gefährliche Arbeiten Soweit es in der jeweiligen Bildungsverordnung vorgesehen ist, sind gefährliche Arbeiten möglich, wenn die Lernenden unter Kontrolle stehen und entsprechend angeleitet werden. Die Anleitung ist in der jeweiligen Bildungsverordnung definiert (resp. im Anhang 2 zum Bildungsplan oder in den begleitenden Massnahmen als Teil des Bildungsplanes).'
#
#
# Was sind gefährliche Arbeiten im Arbeitsgesetz? -|- Das Arbeitsgesetz Gefährliche Arbeiten -|-
# ...

# %%
# create datframe with context and response
df = pd.DataFrame({'context': contexts, 'output': responses})

# write the output to an excel file
df.to_excel(name+'_output.xlsx', index=False, header=False)

# Write the output to another CSV file with '|' delimiter and without header row
df.to_csv(name+'_output.csv', index=False, sep=';', header=False)

df['output'] = df['output'].apply(lambda s: s[:-3])

c = []
q = []
a = []

for row in df.itertuples():
    ## Retrieving data for each row
    context = str(row.context)
    output = str(row.output)
    
    ## Removing “\n" in each string and splitting into question / answer pairs
    output = output.replace('\n', '')
    output = output.split('-|-')
    for i in range(0, len(output) - 1, 2):
        c.append(context)
        q.append(output[i])
        a.append(output[i+1])

tidy_df = pd.DataFrame({'context': c, 'question': q, 'answer': a})

# save tidy_df to csv
tidy_df.to_csv(name+'_tidy.csv', index=False, sep='|', header=False)

#save tidy_df to excel
tidy_df.to_excel(name+'_tidy.xlsx', index=False, header=False)
