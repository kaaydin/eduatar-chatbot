# %%
import pandas as pd

d1 = pd.read_csv('/Users/svenschnydrig/Library/CloudStorage/OneDrive-SharedLibraries-UniversitätSt.Gallen/STUD-NLP Group Project - General/02 Group project/data/data-collection/chatgpt/Questions 1.csv', sep=',')
d2 = pd.read_csv('/Users/svenschnydrig/Library/CloudStorage/OneDrive-SharedLibraries-UniversitätSt.Gallen/STUD-NLP Group Project - General/02 Group project/data/data-collection/chatgpt/Questions 2.csv', sep=',')
d3 = pd.read_csv('/Users/svenschnydrig/Library/CloudStorage/OneDrive-SharedLibraries-UniversitätSt.Gallen/STUD-NLP Group Project - General/02 Group project/data/data-collection/chatgpt/Questions 3.csv', sep=',')
d4 = pd.read_csv('/Users/svenschnydrig/Library/CloudStorage/OneDrive-SharedLibraries-UniversitätSt.Gallen/STUD-NLP Group Project - General/02 Group project/data/data-collection/chatgpt/Questions 4.csv', sep='|')
d5 = pd.read_csv('/Users/svenschnydrig/Library/CloudStorage/OneDrive-SharedLibraries-UniversitätSt.Gallen/STUD-NLP Group Project - General/02 Group project/data/data-collection/chatgpt/Questions 5.csv', sep='|')
# delete last 15 rows of d5
d5 = d5[:-16]

# %%
# concatenate all dataframes vertically
d1_d5 = pd.concat([d1, d2, d3, d4, d5], axis=0)

# delete column 'Titel'
d1_d5 = d1_d5.drop(['Titel'], axis=1)

# %%
d16 = pd.read_csv('/Users/svenschnydrig/Library/CloudStorage/OneDrive-SharedLibraries-UniversitätSt.Gallen/STUD-NLP Group Project - General/02 Group project/data/data-collection/gpt4-api/data/mb16_tidy.csv', sep=',', header=None)
d17 = pd.read_csv('/Users/svenschnydrig/Library/CloudStorage/OneDrive-SharedLibraries-UniversitätSt.Gallen/STUD-NLP Group Project - General/02 Group project/data/data-collection/gpt4-api/data/mb17_tidy.csv', sep='|', header=None)
d19 = pd.read_csv('/Users/svenschnydrig/Library/CloudStorage/OneDrive-SharedLibraries-UniversitätSt.Gallen/STUD-NLP Group Project - General/02 Group project/data/data-collection/gpt4-api/data/mb19_tidy.csv', sep='|', header=None)
d20_301 = pd.read_csv('/Users/svenschnydrig/Library/CloudStorage/OneDrive-SharedLibraries-UniversitätSt.Gallen/STUD-NLP Group Project - General/02 Group project/data/data-collection/gpt4-api/data/mb20_301_tidy.csv', sep='|', header=None)
d302_303 = pd.read_csv('/Users/svenschnydrig/Library/CloudStorage/OneDrive-SharedLibraries-UniversitätSt.Gallen/STUD-NLP Group Project - General/02 Group project/data/data-collection/gpt4-api/data/mb302_303_tidy.csv', sep='|', header=None)

d16_d303 = pd.concat([d16, d17, d19, d20_301, d302_303], axis=0)

# rename columns
d16_d303.columns = ['Kontext', 'Frage', 'Antwort']

# %%
df = pd.concat([d1_d5, d16_d303], axis=0)

df.to_csv('df.csv', index=False)
