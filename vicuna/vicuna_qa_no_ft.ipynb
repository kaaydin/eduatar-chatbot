# %%
#pip install pypdf sentencepiece tiktoken openai chromadb sentence_transformers protobuf==3.20.* langchain

# %% [markdown]
# ## 1.1 Import Libraries

# %%
## Importing DS modules
import pandas as pd

# Importing various components from the langchain library
from langchain.document_loaders import PyPDFDirectoryLoader  # For loading documents from a directory
from langchain.document_loaders import PyPDFLoader  # For loading individual PDF documents
from langchain.embeddings import OpenAIEmbeddings  # For creating embeddings using the OpenAI model
from langchain.text_splitter import CharacterTextSplitter  # For splitting text into characters
from langchain.text_splitter import RecursiveCharacterTextSplitter  # For recursively splitting text into characters
from langchain.vectorstores import Chroma  # For storing and retrieving vectors
from langchain.llms import OpenAI  # For using the OpenAI language model
from langchain.chains import ConversationalRetrievalChain  # For creating a retrieval chain for conversation
from langchain.memory import ConversationBufferMemory  # For storing conversation data in memory

# Additional external library imports
import tiktoken  # A tokenization library from OpenAI

## Importing other modules
import copy
import os

# %% [markdown]
# ## 2.0 Vectorstore Setup

# %%
## Path for documents to be retrieved
DOCUMENT_PATH = "data/raw_data"

## Loading documents to be retrieved
loader = PyPDFDirectoryLoader(DOCUMENT_PATH)
documents = loader.load()

## Choosing the tokenizer model from OpenAI
tiktoken.encoding_for_model("text-davinci-003")
tokenizer = tiktoken.get_encoding('p50k_base')

## Defining function to split the documents into relevant chunks

def tiktoken_len(text):
    tokens = tokenizer.encode(
        text,
        disallowed_special=()
    )
    return len(tokens)

## Defining criteria for splitting documents in relevant chunks to be retrieved 

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=400,
    chunk_overlap=50,
    length_function=tiktoken_len,
    separators=["\n\n", "\n", " ", ""]
)

## Applying text splitter to our document to be retrieved
documents_splitted = text_splitter.split_documents(documents)

## Setting up environment variables for OpenAI
os.environ["OPENAI_API_KEY"] = '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'

## Instantiating the embedding model from OpenAI
embeddings = OpenAIEmbeddings()

## Creating our vectorstore based on the documents_splitted and the OpenAI embedding
vs = Chroma.from_documents(documents_splitted, embeddings)

# %% [markdown]
# ## 3.0 Pipeline Setup

# %%
from langchain.chat_models import ChatOpenAI
from langchain.chains import ConversationChain
from langchain.memory import ConversationBufferMemory

# Data loading
import pandas as pd

# Underlying ML framework
import torch
from torch import nn
import numpy as np

# progress bars
from tqdm.auto import tqdm

# HuggingFace module for transformer
import transformers
from transformers import AutoTokenizer, AutoModelForCausalLM

# HuggingFace module for evaluation
#import evaluate

import sentencepiece

MODEL_PATH = "vicuna-7b"

DEVICE = torch.device("cuda:0")
model = AutoModelForCausalLM.from_pretrained(MODEL_PATH).to(DEVICE)
tokenizer = AutoTokenizer.from_pretrained(MODEL_PATH)

from transformers import pipeline
from langchain.llms import HuggingFacePipeline
import torch
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    max_length=4096,
    temperature=0.2,
    top_p=0.95,
    repetition_penalty=1.15,
    device=0
)

local_llm = HuggingFacePipeline(pipeline=pipe)

# %%
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.docstore.document import Document
from langchain.prompts import PromptTemplate
from langchain.indexes.vectorstore import VectorstoreIndexCreator
from langchain.chains import RetrievalQA
from langchain.chains.question_answering import load_qa_chain
from langchain.prompts import PromptTemplate

# %%
import time

start_time = time.time()
# Your code snippet goes here

chain = load_qa_chain(local_llm, chain_type="stuff")
query = "Wie viele Wochen Ferien habe ich pro Jahr?"
docs = vs.similarity_search(query, k=2)

prompt_template = """Use the following pieces of context to answer the question at the end:

Context in German: "{context}"

Question in German: "{question}"
Answer in German:
"""

PROMPT = PromptTemplate(
    template=prompt_template, input_variables=["context", "question"]
)
chain = load_qa_chain(local_llm, chain_type="stuff", prompt=PROMPT)
result = chain({"input_documents": docs, "question": query}, return_only_outputs=True)
print(result)

end_time = time.time()
execution_time = end_time - start_time

print("Execution time: {:.2f} seconds".format(execution_time))
# Out:
# {'output_text': 'Es gibt keine Informationen darüber, wie viele Wochen Ferien Sie pro Jahr haben.'}
# Execution time: 2.30 seconds

# %% [markdown]
# ## 4.0 Model Evaluation

# %%
def generate_context(query, vectorstore, topk):
    
    contexts = ""
    
    docs = vs.similarity_search(query, k=topk)

    for i in range(topk):
        contexts += docs[i].page_content
        
    contexts.replace('\n', '')
    
    return contexts

context = generate_context(query, vs, 5)
context
# Out:
# 'der wöchentliche Ruhetag innert zweier Wochen \nwenigstens einmal auf einen Sonntag fallen muss \n(Art. 20 Abs. 1 ArG). Damit fällt der wöchentliche \nRuhetag im Laufe eines Jahres mindestens 26 Mal \nauf einen Sonntag. Artikel 12 hält die Möglichkei -\nten fest, wie viele Sonntage in Abweichung von \nder gesetzlichen Regelung pro Jahr frei sein müs -\nsen. Er umschreibt auch, welche Ausgleichsruhe -\nzeiten zu gewähren sind. Die Bestimmung von \nArtikel 21 Absatz 4 ArGV 1 gilt auch für die Tat -\nbestände dieses Artikels. Demnach dürfen die in \ndie Zeit der gesetzlichen Ferien fallenden Sonnta -\nge nicht an die Anzahl frei zu gewährender Sonn -\ntage angerechnet werden. Damit man die freien \nSonntage nach Abzug der Ferien berechnen kann, \nist eine Rechnung pro rata notwendig: Auf 52 Ar -\nbeitswochen sind 26 bzw. 12 freie Sonntag zu ge -\n212 - 1Artikel 12\nAnzahl freie SonntageAbsatz 2\nGilt für einen Betrieb eine wöchentliche Höchst-arbeitszeit von 45 Stunden, so kann bei unregel-mässigem Arbeitsanfall vorübergehend die wö-chentliche Höchstarbeitszeit verlängert werden, um Auslastungsspitzen zu bewältigen. Dabei sind folgende Randbedingungen einzuhalten:\nIm Durchschnitt über das ganze Kalenderjahr ist \ndie Fünftagewoche einzuhalten. Dieser Durch-schnitt errechnet sich wie folgt: \n   365/366 Anzahl Tage des Jahres – XX  Ferientage – 52/53  Ruhetage – 8+1  den Sonntagen gleichgestellte Feier-    tage\n = YYY  Arbeitstage pro Jahr An 5/6 der so berechneten Anzahl von Arbeits-rauffolgenden Woche ist im Anschluss an die tägliche Ruhezeit eine wöchentliche Ruhezeit von \n36 aufeinander folgenden Stunden zu gewähren.\n2bis Im Kalenderjahr sind mindestens 12 freie Sonntage zu gewähren. Sie können unregelmässig auf \ndas Jahr verteilt werden. In der Woche, in der an einem Sonntag gearbeitet wird, oder in der dar -\nauffolgenden Woche ist eine wöchentliche Ruhezeit von 47 aufeinanderfolgenden Stunden oder \nvon zweimal 35 aufeinanderfolgenden Stunden zu gewähren.\n3   Wird im Durchschnitt des Kalenderjahres die Fünf-Tage-Woche gewährt, so kann die Anzahl freie \nSonntage bis auf vier herabgesetzt werden. Die freien Sonntage können unregelmässig auf das \nJahr verteilt werden.\nSECO, April  2022ArGV 2 Art. 12Wegleitung zur Verordnung 2 zum Arbeitsgesetz\n2. Abschnitt: Sonderbestimmungen\nArt. 12 Anzahl freie Sonntage\nwähren. Hat die Arbeitnehmerin oder der Arbeit -\nnehmer Anspruch auf 4 Wochen Ferien, so sind \nihr oder ihm die Anzahl Sonntage nach folgender \nBerechnung zu gewähren:\nAnzahl freie Anzahl freie Sonntage nach ArG x Arbeitswochen      = Sonntage   52 Wochen\nHat die Arbeitnehmerin oder der Arbeitnehmer \nz.B. 26 freie Sonntage und arbeitet während 48 \nWochen im Kalenderjahr, so besteht ein Anrecht \nauf 24 freie Sonntage.\nAbsatz 1 \nDie Anzahl der pro Kalenderjahr frei zu gewähren -\nden Sonntage wird gegenüber dem Gesetz nicht \nreduziert und beträgt ebenfalls 26. Hingegen kön -\nnen diese freien Sonntage unregelmässig auf das Allgemeines\nDas Gesetz geht grundsätzlich davon aus, dass \nder wöchentliche Ruhetag innert zweier Wochen \nwenigstens einmal auf einen Sonntag fallen mussArtikel 12 Absatz 2\nDen Arbeitnehmern und Arbeitnehmerinnen sind im Kalenderjahr mindestens 12 freie Sonntage zu gewähren. Freie Sonntage, die in die gesetzlichen Mindestferien fallen, dürfen nicht an die frei zu gewährenden Sonntage angerechnet werden. In denjenigen Wochen, in denen an einem Sonntag gearbeitet wird, ist im unmittelbaren Anschluss an die tägliche Ruhezeit eine wöchentliche Ruhezeit von 36 Stunden (also insgesamt 47 Stunden) zu gewähren.\nArtikel 14 Absatz 1\nDer wöchentliche freie Halbtag, der neben dem wöchentlichen Ruhetag anfällt, kann für acht Wo-chen zusammengefasst werden. Das bedeutet, dass in einzelnen Wochen an sechs Tagen gear-beitet werden darf. Nach Artikel 21 Absatz 2 ArG ist dazu allerdings das Einverständnis des Arbeit-nehmers bzw. der Arbeitnehmerin nötig.'

# %%
## Retrieving test data
TEST_PATH = "data/test.csv"
TEST_SAVE_PATH = "data"

test = pd.read_csv(TEST_PATH)

## Name of model currently to be evaluated
model_name = "evaluation_vicuna_k=3"

## Collecting context & answers based on test data

answers = []
contexts = []
questions = []

#test2 = test[0:2]

for row in test.itertuples():  
    print('new')
    k = 3
    
    chain = load_qa_chain(local_llm, chain_type="stuff")
    
    ## Retrieving question from test
    query = str(row.Frage)
    docs = vs.similarity_search(query, k=k)
    
    prompt_template = """Use the following pieces of context to answer the question at the end:

    Context in German: "{context}"

    Question in German: "{question}"
    Answer in German:
    """

    PROMPT = PromptTemplate(template=prompt_template, input_variables=["context", "question"])

    chain = load_qa_chain(local_llm, chain_type="stuff", prompt=PROMPT)
    result = chain({"input_documents": docs, "question": query}, return_only_outputs=True)
    answer = result['output_text'].replace('\n', '')
    print(answer)
    
    ## Appending to the list
    questions.append(query)
    answers.append(answer)
    context = generate_context(query, vs, k)
    contexts.append(context)

## Adding answers to list 
evaluation = pd.DataFrame({'context': contexts, 'question': questions, 'answer': answers})
evaluation.to_csv(os.path.join(TEST_SAVE_PATH, f'{model_name}.csv'), index=False)
# Out:
# new
# /home/user/.venv/lib/python3.10/site-packages/transformers/pipelines/base.py:1070: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Ja, es gibt Regelungen für die Nacht- und Sonntagsarbeit von Lehrlingen in der Schweiz. Laut Artikel 14 des Arbeitsgesetzes (ArG) kann die kantonale Behörde vorübergehend Sonntagsarbeitsbewilligungen erteilen, wenn dies aus besonderen Gründen erforderlich ist. Darüber hinaus gibt es auch spezielle Regelungen für bestimmte Branchen wie die Bäckerei, Konfitüre und Confiserie. Insgesamt gibt es jedoch einige Beschränkungen für die Nacht- und Sonntagsarbeit von Lehrlingen, insbesondere in Bezug auf die maximalen Arbeitszeiten und die Anzahl der Arbeitstage.
# new
# * Lernenden, die in einzelnen Fächern Schwierigkeiten haben, können zusätz
# new
# 1. Als Berufsbildner/in    2. Eine Drittperson (z.B. Vorgesetzte/r, Praxisbildner/in, Personalabteilung usw.)    3. Der Lehrling selbst (falls er noch nicht 18 Jahre alt ist, inklusive gesetzlicher Vertretung)    4. Keine Antwort
# new
#         Die lernende Person bleibt zur Mitunterzeichnung der Entschuldigungen verpflichtet.
# new
# 1. Die maximale Arbeitszeit pro Woche für Lehrlinge in der Schweiz beträgt 45 Stunden (Art. 7 Paragraph 1 Buchstabe c ArV).    2. Es gibt keine gesetzliche Regelung über die maximale Arbeitszeit für Lehrlinge in der Schweiz (Nr. 3).    3. Die maximale Arbeitszeit für Lehrlinge in der Schweiz beträgt 41-45 Stunden pro Woche (Art. 7 Paragraph 1 Buchstabe c ArV).
# new
# 1. Der Lehrvertrag wird zwischen dem Anbieter der schulisch organisierten Grundbildung und dem Anbieter des Praktikums geschlossen.    2. Der Anbieter des Praktikums schliesst einen Praktikumsvertrag mit der lernenden Person ab, der bei der Aufsichtsbehörde genehmigt werden muss, wenn das Praktikum länger als sechs Monate dauert.
# new
# "Die Berufsmaturitätsschule (BMS) ermöglicht es den Schülern, eine dreijährige berufliche Grundbildung mit eidgenössischem Fähigkeitszeugnis (BM 1) zu absolvieren. Die BMS bietet auch die Möglichkeit, nach einer abgeschlossenen beruflichen Grundbildung mit eidgenössischem Fähigkeitszeugnis (BM 2), als Vollzeitangebot oder berufsbegleitend als Teilzeitangebot, einen eidgenössischen Berufsmaturitätszeug
# new
# 1. 9 Stunden    2. 10 Stunden    3. 12 Stunden    4. 14 Stunden
# new
# 1 Die kantonalen Behörden meldeten Lehrlinge zur Abschlussprüfung an.
# new
#         Die Lernenden sollten sich bei der Arbeitslosenkasse der Wohngemeinde melden, falls bestehende Gefahren von Arbeitslosigkeit auftreten.
# new
# * Art und Dauer der Ausbildung* Der Lohn* Die Probezeit* Die Arbeitszeit* Die Ferien
# new
# ```vbnetEs besteht keine Pflicht zur Unterzeichnung eines neuen Arbeitsvertrags nach Beendigung der Lehrzeit in der Schweiz. Jedoch können die Lehrenden ggf. neue Ausbildungsplätze suchen oder sich Informationen über andere Berufe holen, falls sie eine Berufliche Neuorientierung wünschen. Infolge der Lehrvertragsauflösung wird die obligatorische Unfallversicherung erlöschen, wenn innerhalb von 31 Kalendertagen kein neuer Lehrvertrag abgeschlossen wird. Wenn dies der Fall ist, wird das Bundesgesetz dazu verpflichtet, die Unfallversicherung zu aktiven. Es gibt jedoch keinen Zwang zur Unterzeichnung eines neuen Arbeitsvertrags.```
# new
#         Die Probezeit darf nicht weniger als einen Monat und nicht mehr als drei Monate betragen. Wenn die Probezeit im Lehrvertrag nicht genau festgelegt ist, beträgt sie drei Monate. Es besteht jedoch eine Verlängerungsmöglichkeit bis auf sechs Monate, soweit die kantonale Behörde zustimmt (OR Art. 344a). Die Verlängerung muss begründet werden.                Die Probezeit beginnt mit dem Antritt der Grundbildung unter dem entsprechenden Lehrvertrag. Wenn ein Lehrvertrag nur für einen Bildungsteil abgeschlossen wird, dauert die Probezeit für diesen Teil in der Regel einen Monat.                Die Bestimmungen über den Lehrvertrag gelten auch dann für betrieblich organisierte Grundbildungen, wenn diese mit einem längeren schulischen Teil beginnen. Die kantonale Behörde kann Ausnahmen vorsehen, wenn sie der lernenden Person gerecht wird.                Die Probezeit kann vor ihrem Ablauf durch Abrede der Parteien und unter Zustimmung der kantonalen Behörde ausnahmsweise bis auf sechs Monate verlängert werden (OR 344a). Die Verlängerung bedarf der Zustimmung des Berufsbildungsamts.```Wenn das Lehrverhältnis während der Probezeit aufgelöst wird, kann die einseitige Auflösung per Kündigung mit einer Kündigungsfrist von sieben Tagen jederzeit stattfinden. Die auflösende Partei muss das Berufsbildungsamt unverzüglich informieren. Die Gründe der Auflösung müssen erklärt werden. Das Schreiben muss vor Ablauf der Probezeit und mit Unterschrift der auflösenden Partei zugestellt werden.Wenn das Lehrverhältnis nach Ablauf der Probezeit aufgelöst wird, bleibt es ein befristetes Arbeitsverhältnis. Eine weitere Kündigung ist jedoch erst nach Ablauf der Vertragsdauer möglich.```
# new
# "Ja, die Krankentaggeldversicherung ist in der Schweiz gesetzlich vorgeschrieben. Die Krankentaggeldversicher
# new
#         * Wenn es aufgrund von Na
# new
# ```vbnetNein, sie dürfen nicht zu Überzeitarbeit herangezogen werden, außer bei Behebung einer Betriebsstörung infolge höherer Gewalt, wie das Bundesgesetz besagt (Art. 31 Abs. 3 ArG). Während der beruflichen Grundbildung sollten sie nicht über 9 Stunden pro Tag arbeiten, wie auch das Arbeitsrecht besagt (Art. 31 Abs. 1 ArG).```
# new
# "Wenn die Höchstarbeitszeit für Lehrlinge in der Schweiz überschritten wird, ist dies strafbar und kann mit Geldstrafe geahndet werden. Es gibt jedoch einige Ausnahmen, z.B. wenn die Überschreitung notwendig ist, um einen bestehenden Notfall zu lösen oder um sicherzustellen, dass die Arbeit ordnungsgemäß ausgeführt wird."
# new
#       * Ja, Lehrlinge haben in der Schweiz Anspruch auf eine Nachtzulage. Die Regelung zur Nachtzulage findet sich in Art. 17b Arbeitsgesetz (ArG) und besagt, dass Arbeitnehmer und Arbeitnehmerinnen mit weniger als 25 Nachteinsätzen leisten vorübergehende Nachtarbeit. Wenn die Arbeitnehmer und Arbeitnehmerinnen mehr als 25 Nachteinsätze in einem Kalenderjahr leisten, haben sie Anspruch auf einen Zeitzuschlag von mindestens 25%. Der Zeitzuschlag berechnet sich basierend auf der tatsächlich geleisteten Arbeitszeit in der Nacht. Wenn der Zeitzuschlag erst im Laufe des Jahres ermittelt wird, kann er erst ab dem Zeitpunkt ausgezahlt werden, an dem die Überschreitung von 25 Nachteilen festgestellt wurde. Der Lohnzuschlag von 25% für die ersten 25 Nachteinsätze darf nicht in den Zeitzuschlag umgewandelt werden. SECO, November 2006."
# new
# * Die Kantone haben die Organisationen der Arbeitswelt bei der Bildung von Trägerschaften für die Kurse zu unterstützen (BBV Art. 21)* Der Lehrbetrieb muss die mit dem Besuch der überbetrieblichen Kurse anfallenden Kosten tragen (BBV Art. 21 Abs. 3)* Organisatorische Lösungen sollten gefunden werden, um eine vernünftige Kursdurchführung ohne Einschränkung der schulischen Bildung zu ermöglichen (BBV Art. 21)* Die lernende Person und ihre gesetzliche Vertretung haben Pflichten (OR Art. 345)* Die Leistungen der Lernenden werden in Form von Kompetenznachweisen dokumentiert (BBV Art. 20)* Die überbetrieblichen Kurse sind für die Lernenden obligatorisch (BBV Art. 21)* Wenn die entsprechenden Bildungsinhalte in einem betrieblichen Bildungszentrum oder in einer externen Lehrwerkstätte vermittelt werden, kann die lernende Person von der Kurspflicht befreit werden (BBV Art. 21)* Eine fachkundige individuelle Begleitung kann bei bestimmten Bedingungen geboten werden (BBV Art. 21)* Freikurse können ohne Lohnabzug besucht werden, wenn im Einverständnis mit dem Betrieb besucht wird (BBV Art. 20)* Im Zweifelsfall entscheidet der Kanton (BBV Art. 20)* Interkantonale Fachkurse können vom SBFIs genehmigt werden, um das Bildungsziel zu verbessern und die Bildungsbereitschaft der Lehrbetriebe zu positiv beeinflussen (BBV Art. 23)
# new
#       * Wenn die Lernenden 6 Lektionen und mehr absolviert haben, kann ein ganzer Schultag angenommen werden.      * Während des Unterrichts an der Berufsfachschule dürfen keine Pausen von der Arbeitszeit abgezogen werden.      * Lehrlinge dürfen während der halben Dauer der Schulferien oder während eines Berufswahlpraktikums maximal acht Stunden pro Tag und 40 Stunden pro Woche arbeiten.      * Die Arbeitszeiten während eines Berufswahlpraktikums müssen jedoch von kurzer Dauer sein und dürfen höchstens zwei Wochen (zehn Arbeitstage) pro Einsatz betragen.
# new
# "Die Lehrvertragsauflösung sollte schriftlich verfasst werden und den Grund für die Auflösung nennen. Es ist wichtig, dass die Auflösung aus wichtigem Grund erfolgt und fristlos sein kann. Wenn die anderen Partei dies verlangt, muss die Auflösung schriftlich begründet werden. Jeder Lehrvertrag ist dem Berufsbildungsamt durch den Lehrbetrieb schriftlich mitzuteilen. Auch das ÜK-Zentrum muss informiert werden. Wenn die Berufsfachschule nicht weiter besucht wird, wird die lernende Person bis zum Ende des Schuljahres informiert. Die Berufsfachschule hat die Auflösung zu bestätigen. Die lernende Person kann die Berufsfachschule während zweier, bzw. maximal dreier Monate weiter besuchen, wenn sie die Ausbildung im selben Beruf fortsetzt. Das Berufsbildungsamt entscheidet je nach Fall, ob die Berufsfachschule weiterbesucht werden kann."
# new
# "Ja, der Lehrbetrieb kann einen Nachweis über die Krankheit verlangen, falls sie durch eine Krankheitshaftungskasse versichert ist. In diesem Fall müssen die Lehrkräfte einen medizinischen Beleg vorlegen, um ihre Entschädigung zu erhalten. Wenn keine Krankheitshaftungskasse verwendet wird, gibt es keine gesetzliche Regelungen zur Bezahlung von Krankheiten. Im Lehrvertrag kann es jedoch vereinbart werden, dass der Lehrbetrieb einen bestimmten Prozentsatz des Bruttolohns während einer Krankheit bezahlt.
# new
# Answer in English: The contract must have a written form and include the following provisions: the type and duration of education, salary, probation period, working hours, and vacations. If there is a violation of public law regulations, only those parts that are not in conflict with public law remain valid.
# new
# 1. Während der Probezeit.    2. In gegenseitigem Einverständnis.    3. Einseitig aus wichtigem Grund.
# new
# "Lehrlinge dürfen an einem Samstag maximal 8 Stunden arbeiten."

# %% [markdown]
# ## 5.0 Memory Chain

# %%
memory = ConversationBufferMemory(memory_key="chat_history", return_messages=True)
qa = ConversationalRetrievalChain.from_llm(local_llm, vs.as_retriever(search_kwargs={"k": 3}), memory=memory)

## Function to retrieve context and answer from model
def query_model(pipeline, query):
    
    ## Retrieving the answer from model based on query
    result = pipeline({"question":query})

    ## Retrieving the answer for query
    answer = result["answer"]

    return answer

## Setting example query
query = "Beantworte die folgende Frage für einen Schweizer Lehrling auf Deutsch: Kann ich in der Lehre unbezahlten Urlaub nehmen?"

## Prompting our model based on example query
result = query_model(qa, query)

## Retrieving the chat history
memory.load_memory_variables({})

# %% [markdown]
# ### 5.1 Improved QA Memory Chain

# %%
from langchain.memory import ConversationBufferMemory
memory = ConversationBufferMemory(memory_key="chat_history", return_messages=True)

from langchain.chains.qa_with_sources import load_qa_with_sources_chain
from langchain.chains import LLMChain
from langchain.chains.conversational_retrieval.prompts import CONDENSE_QUESTION_PROMPT


question_generator = LLMChain(llm=local_llm, prompt=CONDENSE_QUESTION_PROMPT)
doc_chain = load_qa_with_sources_chain(local_llm, chain_type="map_reduce")

chain = ConversationalRetrievalChain(
    retriever=vs.as_retriever(search_kwargs={"k": 3}),
    question_generator=question_generator,
    combine_docs_chain=doc_chain,
)

chat_history = []
query = "Kann ich in der Lehre unbezahlten Urlaub nehmen?"
result = chain({"question": query, "chat_history": chat_history})
result['answer']
